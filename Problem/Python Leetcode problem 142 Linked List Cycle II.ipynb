# %% [markdown]
# # Python Leetcode challenge

# %% [markdown]
# ## 142. Linked List Cycle II (Medium) 20230309
#
# Given the head of a linked list, return the node where the cycle begins. If there is no cycle, return null.
#
# There is a cycle in a linked list if there is some node in the list that can be reached again by continuously following the next pointer. Internally, pos is used to denote the index of the node that tail's next pointer is connected to (0-indexed). It is -1 if there is no cycle. Note that pos is not passed as a parameter.
#
# Do not modify the linked list.

# %% [markdown]
# ### Method 1 (948 ms wins 5.32%, 17.3 MB wins 90.55%)

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def detectCycle(self, head):
        tmp_list = []
        current = head
        while current:
            if current in tmp_list:
                return current
            tmp_list.append(current)
            current = current.next
        return

# %% [markdown]
# 我下面會分享 Method2 (也就是 leetcode 上最佳的解答)，會驚訝地發現其實我使用的解題概念跟 method 2 完全一模一樣，唯一的差別在於 method2 使用的容器是 set 而非 list ，而這將導致執行速度近乎慢了 30 倍，主要原因是因為 set 跟 dict 這兩種資料型態本身是 hash table container ，但 list 本身並非 hash table container ，因此當我們執行 in list 跟 in set 的時候，前者的時間複雜度是 O(n) 後者是 O(1)
#
# https://blog.finxter.com/python-set-add/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Method 2 (54 ms wins 57.68%, 17.9 MB wins 21.35%)

# %%
class Solution:
    def detectCycle(self, head: Optional[ListNode]) -> Optional[ListNode]:
        start=head
        lookup=set()
        while start:
            if start in lookup:
                return start
            else:
                lookup.add(start)
                start=start.next
        return None
